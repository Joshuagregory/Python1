# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline

# %% [markdown]
# # the randn function generates arrays of random numbers whose elements are normally distributed with mean 0, variance , and standard deviation .
# randn(1000)

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
# df.head()
ts.tail(46)
# Out:
# 2022-01-16   -1.825394
# 2022-01-17   -0.238645
# 2022-01-18   -2.118361
# 2022-01-19   -1.342109
# 2022-01-20   -0.301109
# 2022-01-21   -0.440354
# 2022-01-22    0.426402
# 2022-01-23   -1.656202
# 2022-01-24   -1.494867
# 2022-01-25    0.158381
# 2022-01-26    1.374167
# 2022-01-27    0.341467
# 2022-01-28    0.602597
# 2022-01-29   -0.372140
# 2022-01-30    1.282227
# 2022-01-31    1.126091
# 2022-02-01    0.386115
# 2022-02-02   -0.950094
# 2022-02-03    0.455376
# 2022-02-04    0.026712
# 2022-02-05   -0.483069
# 2022-02-06   -0.257269
# 2022-02-07   -0.200678
# 2022-02-08    1.673082
# 2022-02-09    0.387904
# 2022-02-10    0.310410
# 2022-02-11   -0.475922
# 2022-02-12   -0.485315
# 2022-02-13    1.192407
# 2022-02-14   -0.610407
# 2022-02-15    0.204120
# 2022-02-16   -0.111014
# 2022-02-17   -0.608241
# 2022-02-18   -1.315497
# 2022-02-19   -0.444846
# 2022-02-20   -0.311746
# 2022-02-21   -0.774148
# 2022-02-22   -0.772729
# 2022-02-23    0.907183
# 2022-02-24    0.825555
# 2022-02-25    0.119596
# 2022-02-26    0.806424
# 2022-02-27   -0.541438
# 2022-02-28   -0.414802
# 2022-03-01   -0.505259
# 2022-03-02    0.497614
# Freq: D, dtype: float64

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.473758
# 2019-06-08 -1.538031
# 2019-06-09 -1.173609
# 2019-06-10 -0.253631
# 2019-06-11  1.282296

# %%
df.plot()

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.282121
# 2019-06-08    0.067472
# 2019-06-09    0.314854
# 2019-06-10    0.777579
# 2019-06-11   -0.268738
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))

# %%
plt.plot(ts)
plt.rcParams["figure.figsize"] = (5,5)

# %%
iris = sns.load_dataset('iris')
# sns.get_dataset_names()
# iris = pd.read_csv(r'C:\Users\russe\Downloads/iris_dataset.csv')
iris.head() #versicolor,setosa,virginica
# iris[45:90]
# iris.tail()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot()

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
ts.plot.bar()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar',figsize =(10,5))

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.161110  0.437965 -0.306952 -0.976612
# 1  0.153898 -0.404338 -2.224752 -0.567757
# 2 -0.613737  0.652242  1.199046 -1.391184
# 3 -0.420187  1.487347  0.641373 -0.930007
# 4 -1.212419 -0.620421 -0.478124  1.298070
# 5  0.934963 -0.372998 -0.591246 -1.213353
# 6  1.532212 -1.087341 -1.415201 -0.118990
# 7 -1.425754 -1.204612  1.303909  1.470671
# 8  0.016124  0.597208 -1.440096 -0.716916
# 9 -0.642722  0.627905  0.558117 -1.605347

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar',figsize = (7,7))
plt.legend(loc ='lower left')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
x = ['India','USA','Australia','UK','China']
Gold = [50,45,13,15,34]
Silver = [78,56,23,50,67]
Bronze = [26,43,21,68,95]
b_bronze = list(np.add(Gold,Silver))
plt.bar(x,Gold,0.6,label ='Gold')
plt.bar(x,Silver,0.7,label ='Silver',bottom = Gold)#
plt.bar(x,Bronze,0.9,label ='Bronze',bottom = b_bronze)
plt.xlabel('Countries')
plt.ylabel('Medals')
plt.title('Medals vs Countries')
plt.legend()

# %%
medals = pd.read_excel(r'C:\Users\russe\Downloads/medals.xlsx')
df = pd.DataFrame(medals)
df.plot.bar(stacked =False)
plt.title('Medals vs Countries')
# Out:
# Text(0.5, 1.0, 'Medals vs Countries')

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['sepal_width'].plot.hist()

# %%
df = iris.drop(['species'], axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris.hist(color = 'r', alpha = 0.9, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11415EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114E4E20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13D0C5E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11D30C88>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 200)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10DF2C70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10E172F8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10E21DF0>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10E81610>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10E98AA8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10EB05C8>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8),diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x117DF250>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11781520>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11AE4058>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11AFB2E0>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-67-af09896ed1db> in <module>
# ----> 1 from descartes import PolygonPatch
#
# ModuleNotFoundError: No module named 'descartes'

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()

# %%
import geopandas as gpd

# %%
map_df

# %%
import pymongo

# %%
DEFAULT_CONNECTION_URL = "mongodb://localhost:27017/"
DB_NAME = "Josh"

# Establish a connection with mongoDB
client = pymongo.MongoClient(DEFAULT_CONNECTION_URL)

# Create a DB
dataBase = client[DB_NAME]
